# %% [markdown]
# <a href="https://colab.research.google.com/github/adapaania/PrepInsta-Data-Analysis-Internship/blob/main/Week%208/Prep_Insta_Week_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
daily = pd.read_csv("/content/dailyActivity_merged.csv")
hourly = pd.read_csv ("/content/hourlyCalories_merged.csv")
minute = pd.read_csv("/content/minuteCaloriesWide_merged.csv")
sleep = pd.read_csv ("/content/sleepDay_merged.csv")
weight = pd.read_csv ("/content/weightLogInfo_merged.csv")

# %%
daily_cal = pd.read_csv("/content/dailyCalories_merged.csv")
daily_intensities = pd.read_csv ("/content/dailyIntensities_merged.csv")
daily_steps = pd.read_csv("/content/dailySteps_merged.csv")

# %%
daily_cal.head()
# Out:
#            Id ActivityDay  Calories
# 0  1503960366   4/12/2016      1985
# 1  1503960366   4/13/2016      1797
# 2  1503960366   4/14/2016      1776
# 3  1503960366   4/15/2016      1745
# 4  1503960366   4/16/2016      1863

# %%
daily_intensities.head()
# Out:
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366   4/12/2016               728                   328
# 1  1503960366   4/13/2016               776                   217
# 2  1503960366   4/14/2016              1218                   181
# 3  1503960366   4/15/2016               726                   209
# 4  1503960366   4/16/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                 6.06                      0.55                1.88
# ...

# %%
daily_steps.head()
# Out:
#            Id ActivityDay  StepTotal
# 0  1503960366   4/12/2016      13162
# 1  1503960366   4/13/2016      10735
# 2  1503960366   4/14/2016      10460
# 3  1503960366   4/15/2016       9762
# 4  1503960366   4/16/2016      12669

# %%
daily.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
daily.isna().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
hourly_intensities = pd.read_csv("/content/hourlyIntensities_merged.csv")
hourly_steps = pd.read_csv("/content/hourlySteps_merged.csv")

# %%
hourly.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48

# %%
hourly.isna().sum()
# Out:
# Id              0
# ActivityHour    0
# Calories        0
# dtype: int64

# %%
minute.head()
# Out:
#            Id           ActivityHour  Calories00  Calories01  Calories02  \
# 0  1503960366  4/13/2016 12:00:00 AM      1.8876      2.2022      0.9438
# 1  1503960366   4/13/2016 1:00:00 AM      0.7865      0.7865      0.7865
# 2  1503960366   4/13/2016 2:00:00 AM      0.7865      0.7865      0.7865
# 3  1503960366   4/13/2016 3:00:00 AM      0.7865      0.7865      0.7865
# 4  1503960366   4/13/2016 4:00:00 AM      0.7865      0.7865      0.7865
#
#    Calories03  Calories04  Calories05  Calories06  Calories07  ...  \
# 0      0.9438      0.9438      2.0449      0.9438      2.2022  ...
# 1      0.7865      0.9438      0.9438      0.9438      0.7865  ...
# 2      0.7865      0.7865      0.7865      0.7865      0.7865  ...
# 3      0.7865      0.7865      0.7865      0.7865      0.7865  ...
# 4      0.7865      0.7865      0.7865      0.7865      0.7865  ...
#
#    Calories50  Calories51  Calories52  Calories53  Calories54  Calories55  \
# ...

# %%
minute['TotalActivity'] = minute.iloc[:, 3:].sum(axis=1)
minute
# Out:
#               Id           ActivityHour  Calories00  Calories01  Calories02  \
# 0     1503960366  4/13/2016 12:00:00 AM      1.8876      2.2022      0.9438
# 1     1503960366   4/13/2016 1:00:00 AM      0.7865      0.7865      0.7865
# 2     1503960366   4/13/2016 2:00:00 AM      0.7865      0.7865      0.7865
# 3     1503960366   4/13/2016 3:00:00 AM      0.7865      0.7865      0.7865
# 4     1503960366   4/13/2016 4:00:00 AM      0.7865      0.7865      0.7865
# ...          ...                    ...         ...         ...         ...
# 8758  4020332650   5/12/2016 2:00:00 AM      1.3754      1.3754      1.3754
# 8759  4020332650   5/12/2016 3:00:00 AM      1.3754      1.3754      1.3754
# 8760  4020332650   5/12/2016 4:00:00 AM      1.3754      1.3754      1.3754
# 8761  4020332650   5/12/2016 5:00:00 AM      1.3754      1.3754      1.3754
# 8762  4020332650   5/12/2016 6:00:00 AM      1.3754      1.3754      1.3754
#
# ...

# %%
sleep.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep.isna().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
weight.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
import pandas as pd
import matplotlib.pyplot as plt

daily['ActivityDate'] = pd.to_datetime(daily['ActivityDate'])

plt.figure(figsize=(12, 6))

# Total Steps
plt.subplot(3, 1, 1)
plt.plot(daily['ActivityDate'], daily['TotalSteps'], marker='o', linestyle='-', color='b')
plt.title('Total Steps Over Time')
plt.xlabel('Date')
plt.ylabel('Total Steps')

# Total Distance
plt.subplot(3, 1, 2)
plt.plot(daily['ActivityDate'], daily['TotalDistance'], marker='o', linestyle='-', color='g')
plt.title('Total Distance Over Time')
plt.xlabel('Date')
plt.ylabel('Total Distance (in miles)')



# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

# Plot Very Active
axes[0].plot(daily['ActivityDate'], daily['VeryActiveMinutes'], label='Very Active', marker='o', linestyle='-', color='r')
axes[0].set_title('Very Active Minutes Over Time')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Activity Minutes')
axes[0].legend()

# Plot Fairly Active
axes[1].plot(daily['ActivityDate'], daily['FairlyActiveMinutes'], label='Fairly Active', marker='o', linestyle='-', color='y')
axes[1].set_title('Fairly Active Minutes Over Time')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Activity Minutes')
axes[1].legend()

# Plot Lightly Active
axes[2].plot(daily['ActivityDate'], daily['LightlyActiveMinutes'], label='Lightly Active', marker='o', linestyle='-', color='c')
axes[2].set_title('Lightly Active Minutes Over Time')
axes[2].set_xlabel('Date')
axes[2].set_ylabel('Activity Minutes')
axes[2].legend()

plt.tight_layout()  # Adjust layout
plt.show()


plt.tight_layout()
plt.show()

# %%
daily['ActivityDate'] = pd.to_datetime(daily['ActivityDate'])

plt.figure(figsize=(12, 6))

# Very Active Distance
plt.subplot(3, 1, 1)
plt.plot(daily['ActivityDate'], daily['VeryActiveDistance'], marker='o', linestyle='-', color='r')
plt.title('Very Active Distance Over Time')
plt.xlabel('Date')
plt.ylabel('Very Active Distance (in miles)')

# Moderately Active Distance
plt.subplot(3, 1, 2)
plt.plot(daily['ActivityDate'], daily['ModeratelyActiveDistance'], marker='o', linestyle='-', color='g')
plt.title('Moderately Active Distance Over Time')
plt.xlabel('Date')
plt.ylabel('Moderately Active Distance (in miles)')

# Light Active Distance
plt.subplot(3, 1, 3)
plt.plot(daily['ActivityDate'], daily['LightActiveDistance'], marker='o', linestyle='-', color='b')
plt.title('Light Active Distance Over Time')
plt.xlabel('Date')
plt.ylabel('Light Active Distance (in miles)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style for better visualizations
sns.set(style="whitegrid")

# Plot Daily Calorie Consumption Over Time with rolling average
plt.figure(figsize=(12, 6))

# Plot daily calorie consumption
plt.plot(daily['ActivityDate'], daily['Calories'], marker='o', linestyle='-', color='purple', label='Daily Calories')

# Calculate rolling average with window size 7 (weekly)
rolling_avg = daily['Calories'].rolling(window=7).mean()

# Plot rolling average as shaded area
plt.fill_between(daily['ActivityDate'], rolling_avg, color='orange', alpha=0.3, label='7-Day Rolling Average')

plt.title('Daily Calorie Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Calories')
plt.legend()
plt.tight_layout()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)  # Add gridlines
plt.show()

# %%
daily['ActivityDate'] = pd.to_datetime(daily['ActivityDate'])

hourly['ActivityHour'] = pd.to_datetime(hourly['ActivityHour'])

minute['ActivityHour'] = pd.to_datetime(minute['ActivityHour'])

# Merge 'daily' with 'hourly' and 'minute' on the 'Id' and 'ActivityDate' or 'ActivityHour'
daily_hourly_merged = pd.merge(daily, hourly, left_on=['Id', 'ActivityDate'], right_on=['Id', 'ActivityHour'], how='left')
daily_minute_merged = pd.merge(daily, minute, left_on=['Id', 'ActivityDate'], right_on=['Id', 'ActivityHour'], how='left')

plt.figure(figsize=(15, 8))

# %%
# Total Steps vs Minute Calories
plt.subplot(2, 2, 3)
plt.scatter(daily_minute_merged['TotalSteps'], daily_minute_merged['TotalActivity'], alpha=0.5)
plt.title('Total Steps vs Minute Calories')
plt.xlabel('Total Steps')
plt.ylabel('Minute Calories')

# Total Distance vs Minute Calories
plt.subplot(2, 2, 4)
plt.scatter(daily_minute_merged['TotalDistance'], daily_minute_merged['TotalActivity'], alpha=0.5)
plt.title('Total Distance vs Minute Calories')
plt.xlabel('Total Distance')
plt.ylabel('Minute Calories')

plt.tight_layout()
plt.show()

# %%
weight['Date'] = pd.to_datetime(weight['Date'])

plt.figure(figsize=(10, 6))

# Weight Changes Over Time
plt.plot(weight['Date'], weight['WeightKg'], marker='o', linestyle='-', color='orange')
plt.title('Weight Changes Over Time')
plt.xlabel('Date')
plt.ylabel('Weight (Kg)')

plt.tight_layout()
plt.show()

# %%
sleep['SleepDay'] = pd.to_datetime(sleep['SleepDay'])

plt.figure(figsize=(12, 6))

# Total Sleep Records Over Time
plt.subplot(2, 1, 1)
plt.plot(sleep['SleepDay'], sleep['TotalSleepRecords'], marker='o', linestyle='-', color='purple')
plt.title('Total Sleep Records Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sleep Records')



import seaborn as sns

# Convert 'SleepDay' to numerical values
sleep['SleepDay_numeric'] = (sleep['SleepDay'] - sleep['SleepDay'].min()).dt.days

# Set seaborn style for better visualizations
sns.set(style="whitegrid")

# Plot Total Time In Bed Over Time with trendline
plt.figure(figsize=(10, 6))
sns.regplot(x=sleep['SleepDay_numeric'], y=sleep['TotalTimeInBed'], scatter=True, marker='o', color='blue')
plt.title('Total Time In Bed Over Time')
plt.xlabel('Days Since First Recorded SleepDay')
plt.ylabel('Total Time In Bed (minutes)')
plt.tight_layout()
plt.show()



plt.tight_layout()
plt.show()

# %%
daily['ActivityDate'] = pd.to_datetime(daily['ActivityDate'])
sleep['SleepDay'] = pd.to_datetime(sleep['SleepDay'])

# Merge the dataframes based on common identifiers
merged_data = pd.merge(daily, sleep, left_on=['Id', 'ActivityDate'], right_on=['Id', 'SleepDay'], how='left')

# Calculate correlations
correlation_matrix = merged_data[['TotalSteps', 'TotalDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'TotalMinutesAsleep', 'TotalTimeInBed']].corr()

# Plot heatmap of correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix between Sleep and Activity Metrics')
plt.show()

# %%
daily['ActivityDate'] = pd.to_datetime(daily['ActivityDate'])
weight['Date'] = pd.to_datetime(weight['Date'])
sleep['SleepDay'] = pd.to_datetime(sleep['SleepDay'])

# Time series plots for daily metrics
plt.figure(figsize=(14, 8))

# Correlation matrix for daily metrics and sleep patterns
merged_data = pd.merge(daily, sleep, left_on=['Id', 'ActivityDate'], right_on=['Id', 'SleepDay'], how='left')
correlation_matrix = merged_data[['TotalSteps', 'TotalDistance', 'VeryActiveMinutes', 'TotalMinutesAsleep', 'TotalTimeInBed']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix between Daily Metrics and Sleep Patterns')
plt.show()

# Histograms for weight and sleep patterns
plt.figure(figsize=(14, 6))

# Histogram for Weight
plt.subplot(1, 2, 1)
plt.hist(weight['WeightKg'], bins=20, color='orange', edgecolor='black')
plt.title('Weight Distribution')
plt.xlabel('Weight (Kg)')
plt.ylabel('Frequency')

# Histogram for Total Time In Bed
plt.subplot(1, 2, 2)
plt.hist(sleep['TotalTimeInBed'], bins=20, color='purple', edgecolor='black')
plt.title('Total Time In Bed Distribution')
plt.xlabel('Total Time In Bed (minutes)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Fitbit Analysis Report**
#
# **Trends Identified:**
#
# 1. Daily Metrics:
# Total Steps: There is a gradual increase in total steps over time, indicating a potential trend towards a more active lifestyle.
# Total Distance: Similar to total steps, total distance also shows an increasing trend, suggesting an overall increase in physical activity.
# 2. Sleep Patterns:
# Total Sleep Records: The total sleep records show variations over time, suggesting potential changes in sleep patterns or recording habits.
# Total Time In Bed: There might be fluctuations in the total time spent in bed, indicating variations in sleep duration.
# 3. Weight Changes:
# Weight Changes Over Time: The weight changes over time might reveal trends related to weight loss or gain.
#
# **How These Trends Could Apply to Customers:**
#
# 1. Encouraging Physical Activity:
# For Customers: Customers can be encouraged to maintain or increase their physical activity levels for overall health and well-being.
# Marketing Strategy: Promote fitness products, personalized training plans, or challenges to engage customers in reaching step and distance goals.
# 2. Improving Sleep Habits:
# For Customers: Customers might benefit from insights into their sleep patterns, allowing them to make adjustments for better sleep quality.
# Marketing Strategy: Offer sleep-related products, such as sleep trackers, or promote content focused on improving sleep hygiene.
# 3. Weight Management:
# For Customers: Provide weight management solutions, nutritional guidance, or lifestyle interventions based on identified weight trends.
# Marketing Strategy: Create campaigns around healthy eating, fitness programs, or wellness products to support customers in achieving and maintaining a healthy weight.
#
# **How These Trends Could Influence Marketing Strategy:**
#
# 1. Personalized Offerings:
# Utilize insights from daily metrics to tailor personalized product recommendations and services based on individual activity levels and preferences.
# 2. Engagement Through Challenges:
# Implement challenges or competitions centered around increasing daily steps or achieving fitness milestones to boost customer engagement.
# 3. Content and Education:
# Develop content and educational materials addressing the importance of sleep, tips for better sleep, and the relationship between sleep, physical activity, and weight management.
# 4. Targeted Promotions:
# Target marketing promotions based on identified trends, offering discounts on relevant products or services at specific times when customers are more likely to be interested.
# 5. Customer Retention Strategies:
# Implement loyalty programs or rewards for consistent engagement in healthy behaviors, such as maintaining an active lifestyle or improving sleep habits.
